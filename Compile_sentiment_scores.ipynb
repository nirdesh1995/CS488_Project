# %%
import pandas as pd
import nltk 
from nltk.corpus import stopwords 
from nltk.tokenize import sent_tokenize, word_tokenize 
from textblob import TextBlob
from nltk.tokenize import RegexpTokenizer
import re


from os.path import join, exists
import pandas as pd
from os import makedirs
from datetime import date



def return_polarity(article): 
    print("polarity returning")
    return TextBlob(article).sentiment.polarity
    
   
def compile_sentiment_scores(start_date = date(2000,1, 1),end_date=date(2000,2, 1)):
    
    SENTISCORES_DIR = join('data' ,'sentiment_data')
    makedirs(SENTISCORES_DIR, exist_ok=True)
    
    read_file = join('data/dataframes', start_date.strftime('%Y-%m-%d') +'::'+ end_date.strftime('%Y-%m-%d') + '.pkl')    
    file_name = join(SENTISCORES_DIR, start_date.strftime('%Y-%m-%d') +'::'+ end_date.strftime('%Y-%m-%d') + '.pkl')
    
    df = pd.read_pickle(read_file)
    print("filefound and read")
    df['polarity'] = df['bodyText'].apply(return_polarity)
    print('done applying')

    df_polarities = df[['publicationDate','webTitle','sectionId','wordcount','polarity']]

    df_polarities.to_pickle(file_name)
    print('saved to pickle')

# %%
# Out:
#      publicationDate                                           webTitle  \
# 0         2006-01-01                                    Live and Become
# 1         2006-01-01                          Boudu Saved From Drowning
# 2         2006-01-01                                               Rize
# 3         2006-01-01                                   Just Like Heaven
# 4         2006-01-01                             Cheaper by the Dozen 2
# 5         2006-01-01                                Fanny and Alexander
# 6         2006-01-01                Santa pause would spoil all the fun
# 7         2006-01-01             It just won't be the same without Bora
# 8         2006-01-01             Burchill strikes to give Pars lift-off
# 9         2006-01-01                         Broken-foot agony for Owen
# 10        2006-01-01                          Liverpool 1 - 0 West Brom
# 11        2006-01-01                                    Crewe 3 - 4 QPR
# 12        2006-01-01                            Charlton 2 - 0 West Ham
# 13        2006-01-01                          Aston Villa 0 - 0 Arsenal
# 14        2006-01-01                                Derby 2 - 2 Reading
# 15        2006-01-01                           Leinster 35 - 23 Munster
# 16        2006-01-01                         London Irish 19 - 35 Wasps
# 17        2006-01-01        Henson's honesty inoculates us from the pox
# 18        2006-01-01                           Rangers 3 - 0 Dundee Utd
# 19        2006-01-01                              Spurs 2 - 0 Newcastle
# 20        2006-01-01                       Middlesbrough 0 - 0 Man City
# 21        2006-01-01                              Wigan 0 - 3 Blackburn
# 22        2006-01-01                            Portsmouth 1 - 0 Fulham
# 23        2006-01-01                           Chelsea 2 - 0 Birmingham
# 24        2006-01-01                               Man Utd 4 - 1 Bolton
# 25        2006-01-01                           Sunderland 0 - 1 Everton
# 26        2006-01-01           My big night on the tiles with Charlotte
# 27        2006-01-01                                Back from the brink
# 28        2006-01-01   Rix has Hearts pumped for tilt at league leaders
# 29        2006-01-01         Anger over India's threat to Test schedule
# ...              ...                                                ...
# 3830      2006-01-15            Rugby union: Remember Umaga the skipper
# 3831      2006-01-15             Premiership: Liverpool 1 - 0 Tottenham
# 3832      2006-01-15    Horse racing: Running left will put Demon right
# 3833      2006-01-15         Cricket: England still stuck in spin cycle
# 3834      2006-01-15             Cricket: Afridi leads Pakistan plunder
# 3835      2006-01-15                Angry Rooney is confined to margins
# 3836      2006-01-15             Premiership: Charlton 2 - 0 Birmingham
# 3837      2006-01-15                       SPL: Celtic 4 - 2 Kilmarnock
# 3838      2006-01-15                Premiership: Fulham 1 - 0 Newcastle
# 3839      2006-01-15                                   UK news in brief
# 3840      2006-01-15                              DVD club: Intolerance
# 3841      2006-01-15             Football: Wenger hints at Walcott deal
# 3842      2006-01-15                                 It's the new Black
# 3843      2006-01-15  Other films including Memoirs of a Geisha, Bre...
# 3844      2006-01-15                 Championship: Brighton 2 - 1 Leeds
# 3845      2006-01-15                   !?!?xx?! Bush and !?!?xx?! Blair
# 3846      2006-01-15  Jill Insley: Don't pay the claims firms to com...
# 3847      2006-01-15                           Letters: January 15 2006
# 3848      2006-01-15                                           In brief
# 3849      2006-01-15                           Letter from... Frankfurt
# 3850      2006-01-15  Top FTSE companies avoid paying tax to tune of...
# 3851      2006-01-15          Carlyle 'given sweetener' in Qinetiq deal
# 3852      2006-01-15       UK public spending set to outstrip Germany's
# 3853      2006-01-15  Simon Caulkin: Why are we in this pension mess...
# 3854      2006-01-15  Frank Kane: Qinetiq arrogance has sunk this fl...
# 3855      2006-01-15                            The end of Nikonography
# 3856      2006-01-15      William Keegan: Brown can emerge from the web
# 3857      2006-01-15  Leader: All this Britishness is just a trifle ...
# 3858      2006-01-15         Kelly told of schools sex crisis last year
# 3859      2006-01-15                     Monty Don: A bloom with a view
#
#          sectionId wordcount  polarity
# 0             film       696  0.058218
# 1             film       133  0.154028
# 2             film       171  0.086607
# 3             film       188  0.139063
# 4             film       315 -0.093254
# 5             film       190  0.145701
# 6         football      1251  0.086308
# 7         football       664  0.075590
# 8         football       205  0.020175
# 9         football       608  0.029894
# 10        football       854  0.097090
# 11        football       491  0.087957
# 12        football       453  0.026114
# 13        football       529  0.058026
# 14        football       375  0.021089
# 15           sport       565  0.155813
# 16           sport       617  0.148287
# 17           sport       886  0.129795
# 18        football       560  0.009387
# 19        football       670  0.006252
# 20        football       383  0.091119
# 21        football       422  0.163375
# 22        football       438  0.137274
# 23        football       676  0.106709
# 24        football       477  0.135940
# 25        football       587  0.019343
# 26          travel      1554  0.091017
# 27          travel      1318  0.111258
# 28        football       924  0.164393
# 29           sport       714  0.098632
# ...            ...       ...       ...
# 3830         sport       860  0.108107
# 3831      football       734  0.120498
# 3832         sport       695  0.171983
# 3833         sport      1733  0.135251
# 3834         sport       632  0.088747
# 3835      football       889  0.091539
# 3836      football       589  0.072490
# 3837      football       691  0.080462
# 3838      football       717  0.025263
# 3839       uk-news       344  0.114881
# 3840       culture       343  0.269048
# 3841      football       304  0.063254
# 3842   theobserver       402 -0.048547
# 3843   theobserver      1401  0.051804
# 3844      football       444  0.062850
# 3845   theobserver       121  0.099084
# 3846         money       297  0.076667
# 3847   theobserver      1038  0.096511
# 3848         money       923  0.112388
# 3849      business       441  0.200312
# 3850      business       238  0.021651
# 3851      business       508  0.113793
# 3852      business       482 -0.024038
# 3853      business       775  0.127108
# 3854      business      1025  0.042741
# 3855      business       544  0.172758
# 3856      business       927  0.099858
# 3857      politics       213  0.234616
# 3858      politics       906  0.066295
# 3859  lifeandstyle      1197  0.173113
#
# [3860 rows x 5 columns]

# %%
file_name=  join('data/sentiment_data', start_date.strftime('%Y-%m-%d') +'::'+ end_date.strftime('%Y-%m-%d') + '.pkl')
df  = pd.read_pickle(read_file)
# Out:
# 'data/dataframes'

# %%
read_file
# Out:
# 'data/dataframes/2006-01-01::2006-01-15.pkl'
